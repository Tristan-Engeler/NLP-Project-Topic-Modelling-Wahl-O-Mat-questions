# %% [markdown]
# # Make Data Source

# %%
MAKE_EXCEL = True

if MAKE_EXCEL:
    #import packages
    import pandas as pd
    import numpy as np
    import nltk 
    nltk.download('punkt') 

    #import data
    df = pd.read_excel(SOURCE)
    print (df)


    #lower case
    df_text=df[['Question']]
    df_text['Question']=df_text['Question'].str.lower()
    df_text

    #tokenization
    from nltk import word_tokenize
    nltk.download('punkt')
    df_text['Question'] = df_text['Question'].apply(lambda X: word_tokenize(X))
    df_text.head()

    #remove punctuations/special characters
    from nltk.tokenize import RegexpTokenizer
    nltk.download('punkt')

    def remove_punct(text):

        tokenizer = RegexpTokenizer(r"\w+")
        lst = tokenizer.tokenize(' '.join(text))
        return lst

    df_text['Question'] = df_text['Question'].apply(remove_punct)
    df_text

#lemmatization

    from nltk.stem.snowball import GermanStemmer
    stemmer = GermanStemmer()
    from nltk import word_tokenize,pos_tag
    nltk.download('averaged_perceptron_tagger') 

    def lemmatization(text):

        result=[]
        wordnet = GermanStemmer()
        for token,tag in pos_tag(text):
            pos=tag[0].lower()

            if pos not in ['a', 'r', 'n', 'v']:
                pos='n'

            result.append(wordnet.stem(token)) 

        return result

    df_text['Question']=df_text['Question'].apply(lemmatization) 
    df_text
    
    #remove stopwords
    from nltk.corpus import stopwords
    nltk.download('stopwords')

    de_stopwords = stopwords.words('german')
        # we append "werd" to the stopwords list which is missing for better NLP results
    de_stopwords.append("werd")
    
    print(de_stopwords)

    def remove_stopwords(text):
        result = []
        for token in text:
            if token not in de_stopwords:
                result.append(token)

        return result

    df_text['Question'] = df_text['Question'].apply(remove_stopwords)
    df_text

    df_new = pd.DataFrame(df_text)
    print(df_new)

    #download preprocessed df as csv file
    df_new.to_csv(SOURCE)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-5-d68323bc07f5>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['Question']=df_text['Question'].str.lower()
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-5-d68323bc07f5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['Question'] = df_text['Question'].apply(lambda X: word_tokenize(X))
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-5-d68323bc07f5>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['Question'] = df_text['Question'].apply(remove_punct)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#      Year                                           Question  \
# 0    2021  Auf allen Autobahnen soll ein generelles Tempo...
# 1    2021  Deutschland soll seine Verteidigungsausgaben e...
# 2    2021  Bei Bundestagswahlen sollen auch Jugendliche a...
# 3    2021  Die Förderung von Windenergie soll beendet wer...
# 4    2021  Die Möglichkeiten der Vermieterinnen und Vermi...
# ..    ...                                                ...
# 204  2002                     Berufsarmee statt Wehrpflicht.
# 205  2002  Den ärmsten Ländern der Welt müssen die Schuld...
# 206  2002          Der Verteidigungsetat muss erhöht werden.
# 207  2002  Frauen müssen auch ohne vorherige Beratung str...
# 208  2002  Homo-Ehen erhalten die gleichen Rechte wie Het...
#
#                                   Titel
# 0             Tempolimit auf Autobahnen
# 1    Erhöhung der Verteidigungsausgaben
# 2                          Wählen ab 16
# 3                           Windenergie
# 4         Begrenzung für Mieterhöhungen
# ..                                  ...
# 204                                 NaN
# 205                                 NaN
# 206                                 NaN
# 207                                 NaN
# 208                                 NaN
#
# [209 rows x 3 columns]
# ['aber', 'alle', 'allem', 'allen', 'aller', 'alles', 'als', 'also', 'am', 'an', 'ander', 'andere', 'anderem', 'anderen', 'anderer', 'anderes', 'anderm', 'andern', 'anderr', 'anders', 'auch', 'auf', 'aus', 'bei', 'bin', 'bis', 'bist', 'da', 'damit', 'dann', 'der', 'den', 'des', 'dem', 'die', 'das', 'dass', 'daß', 'derselbe', 'derselben', 'denselben', 'desselben', 'demselben', 'dieselbe', 'dieselben', 'dasselbe', 'dazu', 'dein', 'deine', 'deinem', 'deinen', 'deiner', 'deines', 'denn', 'derer', 'dessen', 'dich', 'dir', 'du', 'dies', 'diese', 'diesem', 'diesen', 'dieser', 'dieses', 'doch', 'dort', 'durch', 'ein', 'eine', 'einem', 'einen', 'einer', 'eines', 'einig', 'einige', 'einigem', 'einigen', 'einiger', 'einiges', 'einmal', 'er', 'ihn', 'ihm', 'es', 'etwas', 'euer', 'eure', 'eurem', 'euren', 'eurer', 'eures', 'für', 'gegen', 'gewesen', 'hab', 'habe', 'haben', 'hat', 'hatte', 'hatten', 'hier', 'hin', 'hinter', 'ich', 'mich', 'mir', 'ihr', 'ihre', 'ihrem', 'ihren', 'ihrer', 'ihres', 'euch', 'im', 'in', 'indem', 'ins', 'ist', 'jede', 'jedem', 'jeden', 'jeder', 'jedes', 'jene', 'jenem', 'jenen', 'jener', 'jenes', 'jetzt', 'kann', 'kein', 'keine', 'keinem', 'keinen', 'keiner', 'keines', 'können', 'könnte', 'machen', 'man', 'manche', 'manchem', 'manchen', 'mancher', 'manches', 'mein', 'meine', 'meinem', 'meinen', 'meiner', 'meines', 'mit', 'muss', 'musste', 'nach', 'nicht', 'nichts', 'noch', 'nun', 'nur', 'ob', 'oder', 'ohne', 'sehr', 'sein', 'seine', 'seinem', 'seinen', 'seiner', 'seines', 'selbst', 'sich', 'sie', 'ihnen', 'sind', 'so', 'solche', 'solchem', 'solchen', 'solcher', 'solches', 'soll', 'sollte', 'sondern', 'sonst', 'über', 'um', 'und', 'uns', 'unsere', 'unserem', 'unseren', 'unser', 'unseres', 'unter', 'viel', 'vom', 'von', 'vor', 'während', 'war', 'waren', 'warst', 'was', 'weg', 'weil', 'weiter', 'welche', 'welchem', 'welchen', 'welcher', 'welches', 'wenn', 'werde', 'werden', 'wie', 'wieder', 'will', 'wir', 'wird', 'wirst', 'wo', 'wollen', 'wollte', 'würde', 'würden', 'zu', 'zum', 'zur', 'zwar', 'zwischen', 'werd']
#                                               Question
# 0          [all, autobahn, generell, tempolimit, gelt]
# 1            [deutschland, verteidigungsausgab, erhoh]
# 2       [bundestagswahl, jugend, ab, jahr, wahl, durf]
# 3                        [forder, windenergi, beendet]
# 4    [moglich, vermieterinn, vermiet, wohnungsmiet,...
# ..                                                 ...
# 204                   [berufsarme, statt, wehrpflicht]
# 205                [armst, land, welt, schuld, erlass]
# 206                        [verteidigungsetat, erhoht]
# 207  [frau, ohn, vorher, berat, straffrei, abtreib,...
# 208  [homo, ehen, erhalt, gleich, recht, hetero, eh...
#
# [209 rows x 1 columns]
# <ipython-input-5-d68323bc07f5>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['Question']=df_text['Question'].apply(lemmatization)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-5-d68323bc07f5>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['Question'] = df_text['Question'].apply(remove_stopwords)

# %% [markdown]
# ## Vectorize

# %%
import pandas as pd 

df = pd.read_excel (SOURCE, dtype=str)    # before this, the preprocessed csv file must be converted to an excel file
print (df)

# Vectorization 
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=1, min_df=0)

# apply transformation
tf = vectorizer.fit_transform(df['Question']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
# Out:
#     Unnamed: 0                                           Question
# 0            0  ['all', 'autobahn', 'generell', 'tempolimit', ...
# 1            1    ['deutschland', 'verteidigungsausgab', 'erhoh']
# 2            2  ['bundestagswahl', 'jugend', 'ab', 'jahr', 'wa...
# 3            3                ['forder', 'windenergi', 'beendet']
# 4            4  ['moglich', 'vermieterinn', 'vermiet', 'wohnun...
# ..         ...                                                ...
# 204        204             ['berufsarme', 'statt', 'wehrpflicht']
# 205        205      ['armst', 'land', 'welt', 'schuld', 'erlass']
# 206        206                    ['verteidigungsetat', 'erhoht']
# 207        207  ['frau', 'ohn', 'vorher', 'berat', 'straffrei'...
# 208        208  ['homo', 'ehen', 'erhalt', 'gleich', 'recht', ...
#
# [209 rows x 2 columns]

# %% [markdown]
# # LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation

number_of_topics = 10

model_LDA = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)

model_LDA.fit(tf)

def display_topics(model_LDA, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model_LDA.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

no_top_words = 5
display_topics(model_LDA, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights      Topic 1 words Topic 1 weights  \
# 0            gas             1.1       internetseit             1.1
# 1  transportiert             1.1                fak             1.1
# 2        pipelin             1.1               news             1.1
# 3       russland             1.1              losch             1.1
# 4           nord             1.1  falschinformation             1.1
#
#        Topic 2 words Topic 2 weights    Topic 3 words Topic 3 weights  \
# 0          durchsuch             1.1        finanzier             1.1
# 1  sicherheitsbehord             1.1  energieintensiv             1.1
# 2             comput             1.1             bish             1.1
# 3           verdeckt             1.1         industri             1.1
# 4              onlin             1.1         energiew             1.1
#
#        Topic 4 words Topic 4 weights  Topic 5 words Topic 5 weights  \
# 0  kommunikationsdat             1.1           ehen             2.1
# 1           speicher             1.1   bundesbehord             1.1
# 2            telefon             1.1    unterschied             1.1
# 3           internet             1.1     sprachlich             1.1
# 4             anlass             1.1  veroffentlich             1.1
#
#      Topic 6 words Topic 6 weights Topic 7 words Topic 7 weights  \
# 0       arbeitnehm             1.1   abgerechnet             1.1
# 1  arbeitnehmerinn             1.1       behandl             1.1
# 2          angehor             1.1  fallpauschal             1.1
# 3             zeit             1.1   krankenhaus             1.1
# 4  lohnersatzleist             1.1     stationar             1.1
#
#   Topic 8 words Topic 8 weights      Topic 9 words Topic 9 weights
# 0     verandert             1.1               beim             1.1
# 1       besetzt             1.1  kohlenstoffdioxid             1.1
# 2  lebensmittel             1.1               heiz             1.1
# 3      gentechn             1.1         festgelegt             1.1
# 4   abwechselnd             1.1           ausstoss             1.1

# %% [markdown]
# ## Visualisation of LDA results

# %%
import matplotlib.pyplot as plt

def plot_top_words(model_LDA, tf_feature_names, no_top_words, title='LDA Wahlomat'):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model_LDA.components_):
        top_features_ind = topic.argsort()[: -no_top_words - 1 : -1]
        top_features = [tf_feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    
plot_top_words(model_LDA, tf_feature_names, no_top_words, title='LDA Wahlomat')

# %% [markdown]
# # NMF

# %%
from sklearn.decomposition import NMF  

number_of_topics = 10

model_NMF = NMF(n_components=number_of_topics, random_state=0, alpha=0, l1_ratio=1) 
model_NMF.fit(tf)

def display_topics(model_NMF, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model_NMF.components_):   
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

no_top_words = 10
display_topics(model_NMF, tf_feature_names, no_top_words)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
#        Topic 0 words Topic 0 weights      Topic 1 words Topic 1 weights  \
# 0           ausstoss             1.2              losch             0.7
# 1           autofahr             1.2       internetseit             0.7
# 2               beim             1.2                fak             0.7
# 3              steig             1.2  falschinformation             0.7
# 4         festgelegt             1.2            betreib             0.7
# 5              preis             1.2               wurd             0.7
# 6               heiz             1.2          hingewies             0.7
# 7  kohlenstoffdioxid             1.2               news             0.7
# 8            vorrang             0.0          verwendet             0.0
# 9         mehrausgab             0.0              abbau             0.0
#
#     Topic 2 words Topic 2 weights  Topic 3 words Topic 3 weights  \
# 0            ehen             1.4        pipelin             0.7
# 1          adopti             0.7          ostse             0.7
# 2          gleich             0.7  transportiert             0.7
# 3          hetero             0.7       russland             0.7
# 4   abschlagsfrei             0.0         stream             0.7
# 5    beitragsjahr             0.0            gas             0.7
# 6          bereit             0.0           nord             0.7
# 7  renteneintritt             0.0        gegenub             0.0
# 8          zuwand             0.0        vorrang             0.0
# 9      verpflicht             0.0           tilg             0.0
#
#          Topic 4 words Topic 4 weights    Topic 5 words Topic 5 weights  \
# 0             speicher             0.7          angehor             0.7
# 1              telefon             0.7       arbeitnehm             0.7
# 2               anlass             0.7  arbeitnehmerinn             0.7
# 3              konkret             0.7             zeit             0.7
# 4    kommunikationsdat             0.7            pfleg             0.7
# 5             internet             0.7  lohnersatzleist             0.7
# 6            verwendet             0.0    abschlagsfrei             0.0
# 7  haushaltsuberschuss             0.0     beitragsjahr             0.0
# 8             uberwieg             0.0           bereit             0.0
# 9                abbau             0.0   renteneintritt             0.0
#
#           Topic 6 words Topic 6 weights       Topic 7 words Topic 7 weights  \
# 0  geschlechtsidentitat             0.7         beschaftigt             0.4
# 1          bundesbehord             0.7                selb             0.4
# 2           berucksicht             0.7              erlaub             0.4
# 3            sprachlich             0.7           homeoffic             0.4
# 4           unterschied             0.7              arbeit             0.4
# 5         veroffentlich             0.7                mutt             0.3
# 6               vorrang             0.0        traditionell             0.3
# 7               gegenub             0.0                 vat             0.3
# 8            mehrausgab             0.0  lebensgemeinschaft             0.3
# 9                  tilg             0.0                 and             0.3
#
#    Topic 8 words Topic 8 weights    Topic 9 words Topic 9 weights
# 0   fallpauschal             0.5             bish             0.7
# 1      stationar             0.5        finanzier             0.7
# 2    abgerechnet             0.5         industri             0.7
# 3    krankenhaus             0.5         energiew             0.7
# 4        behandl             0.5  energieintensiv             0.7
# 5       bestimmt             0.4          gymnasi             0.3
# 6  selbstgenutzt             0.4        schulsyst             0.3
# 7         erwerb             0.4            haupt             0.3
# 8   wohneigentum             0.4       gegliedert             0.3
# 9     steuerfrei             0.4        realschul             0.3

# %% [markdown]
# ## Visualization of NMF results

# %%
import matplotlib.pyplot as plt

def plot_top_words(model_NMF, tf_feature_names, no_top_words, title='NMF Wahlomat'):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model_NMF.components_):
        top_features_ind = topic.argsort()[: -no_top_words - 1 : -1]
        top_features = [tf_feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    
plot_top_words(model_NMF, tf_feature_names, no_top_words, title='NMF Wahlomat')

# %% [markdown]
# # GDSMM

# %%
import pandas as pd
import numpy as np
from gsdmm import MovieGroupProcess
import gensim

# cast tweets to numpy array
docs = df['Question'].str.split(' ').to_numpy()

# create dictionary of all words in all documents
dictionary = gensim.corpora.Dictionary(docs)

# filter extreme cases out of dictionary
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=10000)

# create variable containing length of dictionary/vocab
vocab_length = len(dictionary)

# create BOW dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in docs]

# initialize GSDMM
gsdmm = MovieGroupProcess(K=10, alpha=0, beta=0.3, n_iters=10)

# fit GSDMM model
y = gsdmm.fit(docs, vocab_length)
# Out:
# In stage 0: transferred 161 clusters with 10 clusters populated
# In stage 1: transferred 114 clusters with 10 clusters populated
# In stage 2: transferred 97 clusters with 10 clusters populated
# In stage 3: transferred 95 clusters with 10 clusters populated
# In stage 4: transferred 93 clusters with 10 clusters populated
# In stage 5: transferred 85 clusters with 10 clusters populated
# In stage 6: transferred 88 clusters with 10 clusters populated
# In stage 7: transferred 98 clusters with 10 clusters populated
# In stage 8: transferred 84 clusters with 10 clusters populated
# In stage 9: transferred 95 clusters with 10 clusters populated

# %%
doc_count = np.array(gsdmm.cluster_doc_count)
list(zip(range(len(doc_count)), doc_count))
# Out:
# [(0, 20),
#  (1, 21),
#  (2, 18),
#  (3, 18),
#  (4, 19),
#  (5, 23),
#  (6, 21),
#  (7, 23),
#  (8, 27),
#  (9, 19)]

# %%
# print number of documents per topic
doc_count = np.array(gsdmm.cluster_doc_count)
print('Number of documents per topic :', list(zip(range(len(doc_count)), doc_count)))

# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-10:][::-1]
print('Most important clusters (by number of docs inside):', top_index)

# define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

# get top words in topics
top_words(gsdmm.cluster_word_distribution, top_index, 10)
# Out:
# Number of documents per topic : [(0, 20), (1, 21), (2, 18), (3, 18), (4, 19), (5, 23), (6, 21), (7, 23), (8, 27), (9, 19)]
# Most important clusters (by number of docs inside): [8 7 5 6 1 0 9 4 3 2]
#
# Cluster 8 : [("['deutschland',", 11), ("'eingefuhrt']", 5), ("'europa',", 4), ("'union',", 4), ("'fur',", 4), ("'austret']", 3), ("'gelockert']", 3), ("'bedingungslos',", 2), ("'grundeinkomm',", 2), ("'wahrung',", 2)]
#
# Cluster 7 : [("'jahr',", 5), ("['gesetz',", 4), ("['fur',", 4), ("'gesenkt']", 3), ("'eingefuhrt']", 3), ("'sollt',", 3), ("'flachendeck',", 3), ("'erhoht']", 3), ("'mindestlohn',", 2), ("['abgeordnet',", 2)]
#
# Cluster 5 : [("'weiterhin',", 6), ("'abgeschafft']", 5), ("['all',", 3), ("'religionsgemeinschaft',", 3), ("'bleib']", 3), ("['unternehm',", 3), ("'fur',", 2), ("'bank',", 2), ("'verstaatlicht']", 2), ("'vollstand',", 2)]
#
# Cluster 6 : [("'eingesetzt',", 4), ("'offent',", 4), ("'durf']", 3), ("['videouberwach',", 3), ("'hoh',", 3), ("'verbot']", 3), ("['terrorismusbekampf',", 2), ("'bundeswehr',", 2), ("'fur',", 2), ("'inn',", 2)]
#
# Cluster 1 : [("'deutschland',", 4), ("'fur',", 4), ("'deutsch',", 3), ("'steu',", 3), ("'weiterhin',", 3), ("'erhob']", 2), ("'sollt',", 2), ("'legalisiert']", 2), ("'wied',", 2), ("['bund',", 2)]
#
# Cluster 0 : [("'erhalt']", 7), ("'fur',", 6), ("'kind',", 4), ("'generell',", 3), ("'erlaubt']", 3), ("['elt',", 3), ("'bundesland',", 3), ("'mehr',", 3), ("['kontrolliert',", 2), ("'verkauf',", 2)]
#
# Cluster 9 : [("'durf']", 4), ("['einfuhr',", 4), ("'fur',", 4), ("'bundeseb']", 3), ("'ohn',", 3), ("'deutschland',", 3), ("'volksentscheid',", 2), ("'gesetz',", 2), ("['frau',", 2), ("'vorher',", 2)]
#
# Cluster 4 : [("'gesetz',", 9), ("['all',", 6), ("'tempolimit',", 5), ("['generell',", 4), ("'autobahn']", 4), ("'burg',", 3), ("'krankenkass',", 3), ("'versichert']", 3), ("'gelt']", 3), ("'burgerinn',", 2)]
#
# Cluster 3 : [("'stark',", 6), ("'landwirtschaft',", 5), ("'unabhang',", 5), ("'einkomm',", 5), ("'elt',", 5), ("['okolog',", 4), ("'finanziell',", 4), ("['bafog',", 3), ("'gezahlt']", 3), ("'staat',", 3)]
#
# Cluster 2 : [("'weiterhin',", 5), ("'durf']", 5), ("'deutsch',", 5), ("'kind',", 3), ("['deutschland',", 3), ("'staatsangehor',", 3), ("'neb',", 2), ("'zweit',", 2), ("'ohn',", 2), ("'verbot',", 2)]

# %% [markdown]
# ## BERT

# %%
doc = df['Question']
doc
# Out:
# 0      ['all', 'autobahn', 'generell', 'tempolimit', ...
# 1        ['deutschland', 'verteidigungsausgab', 'erhoh']
# 2      ['bundestagswahl', 'jugend', 'ab', 'jahr', 'wa...
# 3                    ['forder', 'windenergi', 'beendet']
# 4      ['moglich', 'vermieterinn', 'vermiet', 'wohnun...
#                              ...
# 204               ['berufsarme', 'statt', 'wehrpflicht']
# 205        ['armst', 'land', 'welt', 'schuld', 'erlass']
# 206                      ['verteidigungsetat', 'erhoht']
# 207    ['frau', 'ohn', 'vorher', 'berat', 'straffrei'...
# 208    ['homo', 'ehen', 'erhalt', 'gleich', 'recht', ...
# Name: Question, Length: 209, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

ngram_range = (2,2)

count = CountVectorizer(ngram_range=ngram_range)
X = count.fit_transform(doc)
candidates = count.get_feature_names()
candidates
# Out:
# ['16 jahr',
#  'ab jahr',
#  'abbau staatsschuld',
#  'abgebaut durf',
#  'abgeordnet bundestag',
#  'abgeordnet verpflichtet',
#  'abschlagsfrei moglich',
#  'abtreib durf',
#  'abwechselnd frau',
#  'acht jahr',
#  'adoptionsrecht erhalt',
#  'adoptionsrecht fur',
#  'afghanistan abgezog',
#  'agrarsubvention deutlich',
#  'aktiv wahlrecht',
#  'all autobahn',
#  'all bank',
#  'all bundesland',
#  'all burg',
#  'all burgerinn',
#  'all dauerhaft',
#  'all deutsch',
#  'all erwerbstat',
#  'all kind',
#  'all nebeneinkunft',
#  'all straftat',
#  'allein fur',
#  'and lebensgemeinschaft',
#  'anerkannt fluchtling',
#  'anerkannt konn',
#  'angab grund',
#  'angehob durf',
#  'angehor pfleg',
#  'angeleg bundesland',
#  'anspruch bafog',
#  'anspruch nehm',
#  'ansteck krankheit',
#  'antisemitismus stark',
#  'arbeit homeoffic',
#  'arbeitnehm fur',
#  'arbeitnehmerinn arbeitnehm',
#  'arbeitslosengeld ii',
#  'arbeitsvermittl sollt',
#  'arbeitsvertrag weiterhin',
#  'armst land',
#  'asyl erhalt',
#  'asyl weiterhin',
#  'asylsuch jahrlich',
#  'atomenergi festgehalt',
#  'atomkraftwerk verlangert',
#  'aufgab inn',
#  'aufgewachs kind',
#  'aufnahm neu',
#  'aufsichtsrat borsennotiert',
#  'aufsichtsrat vorstand',
#  'auftrag fur',
#  'ausbau erneuerbar',
#  'ausbau kommunikationsinfrastruktur',
#  'ausbildungsplatz gesetz',
#  'ausland elt',
#  'ausland lebend',
#  'ausnahmslos verbot',
#  'ausschliess angeleg',
#  'ausstieg atomenergi',
#  'ausstieg kohleverstrom',
#  'ausstoss kohlenstoffdioxid',
#  'auszubild unabhang',
#  'autobahn generell',
#  'autobahn kostenpflicht',
#  'autofahr stark',
#  'autos verbrennungsmotor',
#  'bafog generell',
#  'bafog sollt',
#  'bafog unabhang',
#  'bahn vollstand',
#  'bank darf',
#  'bank deutschland',
#  'bank verstaatlicht',
#  'beamtinn dien',
#  'bedingungslos grundeinkomm',
#  'befristet durf',
#  'begang straftat',
#  'begrenzt angehob',
#  'begrenzt konn',
#  'behalt durf',
#  'behandl krankenhaus',
#  'beim heiz',
#  'beitragsjahr renteneintritt',
#  'beitritt turkei',
#  'bekampf antisemitismus',
#  'benzinsteu senk',
#  'berat dritt',
#  'berat straffrei',
#  'bereit beitragsjahr',
#  'berufsarme statt',
#  'beschaft durf',
#  'beschaftigt arbeit',
#  'besetz fuhrungsposition',
#  'besitz durf',
#  'best staatsform',
#  'bestandteil deutsch',
#  'besteh bleib',
#  'bestimmt hoh',
#  'beteil privat',
#  'betreib internetseit',
#  'betreuungsgeld erhalt',
#  'betrieb geh',
#  'betrieb gemeind',
#  'betrieb kundigungsschutz',
#  'bildungspolit ausschliess',
#  'bildungspolit landersach',
#  'biometr dat',
#  'bish finanzier',
#  'borsennotiert unternehm',
#  'braunkohl abgebaut',
#  'bund dauerhaft',
#  'bund mehr',
#  'bund projekt',
#  'bund sollt',
#  'bund weiterhin',
#  'bundesbehord veroffentlich',
#  'bundeseb eingefuhrt',
#  'bundesland einfuhr',
#  'bundesland schwach',
#  'bundesland wenig',
#  'bundesprasident sollt',
#  'bundesrepubl best',
#  'bundestag abwechselnd',
#  'bundestag nebeneinkunft',
#  'bundestagswahl jugend',
#  'bundestagswahl wahl',
#  'bundeswehr fur',
#  'bundeswehr inland',
#  'bundeswehr inn',
#  'bundeswehr polizei',
#  'bundeswehr sofort',
#  'burg gesetz',
#  'burg inn',
#  'burgerinn burg',
#  'cannabis generell',
#  'chines firm',
#  'christlich wert',
#  'comput sicherheitsbehord',
#  'covid weiterhin',
#  'danach rezeptpflicht',
#  'darf vorubergeh',
#  'dat fingerabdruck',
#  'dat genet',
#  'dauerhaft deutschland',
#  'dauerhaft finanziell',
#  'demokrati bundesrepubl',
#  'deutlich angehob',
#  'deutlich gesenkt',
#  'deutsch autobahn',
#  'deutsch bundestag',
#  'deutsch deutschland',
#  'deutsch erinnerungskultur',
#  'deutsch famili',
#  'deutsch firm',
#  'deutsch grenz',
#  'deutsch polit',
#  'deutsch staatsangehor',
#  'deutsch steinkohl',
#  'deutsch zweit',
#  'deutschland asyl',
#  'deutschland ausnahmslos',
#  'deutschland bedingungslos',
#  'deutschland digital',
#  'deutschland erhalt',
#  'deutschland erhoht',
#  'deutschland eu',
#  'deutschland euro',
#  'deutschland europa',
#  'deutschland fur',
#  'deutschland gebor',
#  'deutschland generell',
#  'deutschland gentechn',
#  'deutschland leb',
#  'deutschland legalisiert',
#  'deutschland mehr',
#  'deutschland national',
#  'deutschland nato',
#  'deutschland schuldenschnitt',
#  'deutschland steu',
#  'deutschland transportiert',
#  'deutschland unterstutz',
#  'deutschland verstaatlicht',
#  'deutschland verteidigungsausgab',
#  'deutschland zukunft',
#  'dien generell',
#  'dien verstarkt',
#  'dienstleist erzielt',
#  'dieselkraftstoff fur',
#  'digital dienstleist',
#  'direkt gewahlt',
#  'dna dat',
#  'dosenpfand abgeschafft',
#  'dritt monat',
#  'durchsuch privat',
#  'ehegattensplitting beibehalt',
#  'ehen erhalt',
#  'ehen kind',
#  'ehepaar ohn',
#  'eigenbeteil gesundheitsbereich',
#  'einfuhr flachendeck',
#  'einfuhr gesetz',
#  'einfuhr verbind',
#  'einfuhr volksentscheid',
#  'eingesetzt durf',
#  'eingesetzt konn',
#  'einkomm elt',
#  'einkommensteuersatz gesenkt',
#  'einreisekontroll durchgefuhrt',
#  'einschul spracht',
#  'elt anspruch',
#  'elt erhalt',
#  'elt fur',
#  'elt gezahlt',
#  'elt kind',
#  'elt weiterhin',
#  'elternzeit erziehungsurlaub',
#  'empfang empfangerinn',
#  'empfangerinn weiterhin',
#  'end grundschulzeit',
#  'end vollstand',
#  'energi bund',
#  'energieintensiv industri',
#  'energiew beteil',
#  'entscheid beschaftigt',
#  'entscheid konn',
#  'entsprech gekurzt',
#  'erhalt durf',
#  'erhalt erleichtert',
#  'erhalt gleich',
#  'erhoh gesetz',
#  'erhoh steu',
#  'erneuerbar energi',
#  'erst jahr',
#  'erststudium gebuhrenfrei',
#  'erwerb selbstgenutzt',
#  'erwerbstat gesetz',
#  'erziehungsurlaub lohnersatz',
#  'erzielt national',
#  'eu austret',
#  'eu erhalt',
#  'euro erhoht',
#  'euro genau',
#  'euro wahrung',
#  'euro zon',
#  'europa agrarsubvention',
#  'europa jud',
#  'europa union',
#  'europa verteidigungspolit',
#  'fak news',
#  'fallpauschal abgerechnet',
#  'falschinformation fak',
#  'famili ausgezahlt',
#  'famili vat',
#  'familiennachzug abgeschafft',
#  'festgelegt preis',
#  'finanziell forder',
#  'finanziell gefordert',
#  'finanziell stark',
#  'finanziell unterstutz',
#  'finanzier energiew',
#  'finanzstark bundesland',
#  'fingerabdruck personalausweis',
#  'fingerabdruck zentral',
#  'firm auftrag',
#  'flachendeck eingefuhrt',
#  'flachendeck gesetz',
#  'flachendeck mindestlohn',
#  'fluchtling aufnehm',
#  'fluchtling familiennachzug',
#  'fluchtling integrationsmassnahm',
#  'flugverkehr hoh',
#  'forder erhalt',
#  'forder windenergi',
#  'form beibehalt',
#  'frau mann',
#  'frau ohn',
#  'frauenquot fur',
#  'frauenquot gelt',
#  'frei entscheid',
#  'fuhrungsposition gesetz',
#  'fur all',
#  'fur arbeitslosengeld',
#  'fur aufgab',
#  'fur aufnahm',
#  'fur aufsichtsrat',
#  'fur ausbau',
#  'fur ausstoss',
#  'fur begang',
#  'fur beitritt',
#  'fur gleichgeschlecht',
#  'fur griechenland',
#  'fur jahr',
#  'fur kind',
#  'fur pkw',
#  'fur religionsgemeinschaft',
#  'fur schuld',
#  'fur schulpolit',
#  'fur sozial',
#  'fur spitzenverdi',
#  'fur unternehm',
#  'fur wahl',
#  'fur zeit',
#  'fur zuwand',
#  'ganztagsbetreu erhalt',
#  'ganztagsschul flachendeck',
#  'gas russland',
#  'gebor aufgewachs',
#  'gefordert konventionell',
#  'geg ansteck',
#  'geg covid',
#  'geg rechtsextremismus',
#  'gegenub mehrausgab',
#  'gegliedert schulsyst',
#  'geh betreuungsgeld',
#  'geh durf',
#  'gekurzt jobangebot',
#  'gekurzt konn',
#  'gemeind begrenzt',
#  'gemeinsam adoptionsrecht',
#  'gemeinsam europa',
#  'gemeinsam unterrichtet',
#  'gemeinschaftsschulzeit sollt',
#  'genau offenleg',
#  'generell erlaubt',
#  'generell moglich',
#  'generell tempolimit',
#  'generell unabhang',
#  'generell verbot',
#  'genet fingerabdruck',
#  'genomforsch verbot',
#  'gentechn verandert',
#  'geplant ausstieg',
#  'geplant betrieb',
#  'gesamtzahl nutzti',
#  'geschaft sonntag',
#  'geschlechtsidentitat sprachlich',
#  'gesetz flachendeck',
#  'gesetz frauenquot',
#  'gesetz garantiert',
#  'gesetz gleichstell',
#  'gesetz krankenkass',
#  'gesetz mindestlohn',
#  'gesetz rent',
#  'gesetz renteneintrittsalt',
#  'gesetz rentenversicher',
#  'gesetz stark',
#  'gesetz verpflichtet',
#  'gesichtserkennungssoftwar eingesetzt',
#  'gleich recht',
#  'gleichgeschlecht lebenspartnerschaft',
#  'gleichstell homo',
#  'gottesbezug grundgesetz',
#  'grenz wied',
#  'griechenland zustimm',
#  'grund befristet',
#  'grundeinkomm eingefuhrt',
#  'grundeinkomm geb',
#  'grundgesetz beibehalt',
#  'grundgesetz besteh',
#  'grundschulzeit rechtsanspruch',
#  'gymnasi beibehalt',
#  'handelsbezieh staat',
#  'hartz iv',
#  'haschisch legalisiert',
#  'haschisch marihuana',
#  'haupt realschul',
#  'haushaltsuberschuss uberwieg',
#  'heiz autofahr',
#  'hetero ehen',
#  'hingewies wurd',
#  'hintergrund gemeinsam',
#  'hoch einkommensteuersatz',
#  'hoh besteuert',
#  'hoh managergehalt',
#  'hoh steuerfrei',
#  'hoh vermog',
#  'homeoffic erlaub',
#  'homo ehe',
#  'homo ehen',
#  'human genomforsch',
#  'ii hartz',
#  'impfstoff geg',
#  'industri stark',
#  'inland eingesetzt',
#  'inn auszubild',
#  'inn dna',
#  'inn eingesetzt',
#  'inn gesetz',
#  'inn verstarkt',
#  'innerhalb deutschland',
#  'integrationsangebot kurs',
#  'integrationsmassnahm verweig',
#  'internet ohn',
#  'internetseit gesetz',
#  'islam verband',
#  'iv deutlich',
#  'iv empfang',
#  'jahr elternzeit',
#  'jahr erhoht',
#  'jahr geplant',
#  'jahr gesenkt',
#  'jahr mindest',
#  'jahr verurteilt',
#  'jahr wahl',
#  'jahrlich obergrenz',
#  'jed jugend',
#  'jed kind',
#  'jed staat',
#  'jetzig form',
#  'jobangebot ablehn',
#  'jud weiterhin',
#  'jugend ab',
#  'jugend ausbildungsplatz',
#  'kampfhund sollt',
#  'kind adopti',
#  'kind ausland',
#  'kind einschul',
#  'kind end',
#  'kind geg',
#  'kind kita',
#  'kind krippenplatz',
#  'kind stark',
#  'kind ungeachtet',
#  'kind unt',
#  'kind vorschulalt',
#  'kind weiterhin',
#  'kindergeld deutsch',
#  'kirchensteu einzieh',
#  'kita geh',
#  'kohlenstoffdioxid beim',
#  'kohleverstrom vorgezog',
#  'kommunal wahlrecht',
#  'kommunikationsdat telefon',
#  'kommunikationsinfrastruktur deutschland',
#  'konkret anlass',
#  'kontrolliert verkauf',
#  'konventionell landwirtschaft',
#  'kopftuch beamtinn',
#  'krankenhaus weiterhin',
#  'krankenkass versich',
#  'krankenkass versichert',
#  'krankheit geimpft',
#  'krippenplatz anspruch',
#  'kulturell hintergrund',
#  'kundigungsschutz gelockert',
#  'kurs geb',
#  'land welt',
#  'landersach bleib',
#  'landeslist partei',
#  'landwirtschaft betrieb',
#  'landwirtschaft finanziell',
#  'landwirtschaft staat',
#  'landwirtschaft stark',
#  'langfrist moglich',
#  'laufzeit atomkraftwerk',
#  'lebend deutsch',
#  'lebensgemeinschaft gefordert',
#  'lebensmittel produziert',
#  'lebenspartnerschaft gemeinsam',
#  'leiharbeit beschaft',
#  'leiharbeiterinn leiharbeit',
#  'leistung gekurzt',
#  'leitbild deutsch',
#  'lohn sink',
#  'lohnersatz zahl',
#  'lohnersatzleist erhalt',
#  'lohnnebenkost gesenkt',
#  'losch hingewies',
#  'managergehalt frei',
#  'mann besetzt',
#  'marihuana legalisiert',
#  'mark wied',
#  'mehr eigenbeteil',
#  'mehr fluchtling',
#  'mehr mittel',
#  'mehr videouberwach',
#  'mehr zustand',
#  'mehrausgab bildungsbereich',
#  'mehrwertsteu erhoht',
#  'mensch migrationshintergrund',
#  'menschenrecht missacht',
#  'mietpreis begrenzt',
#  'migrationshintergrund einstell',
#  'mindest euro',
#  'mindestlohn eingefuhrt',
#  'mindestlohn spatest',
#  'missacht eingestellt',
#  'mitglied europa',
#  'mitgliedstaat europa',
#  'mittel fur',
#  'moglich deutschland',
#  'moglich neb',
#  'moglich vermieterinn',
#  'monat straffrei',
#  'mutt kind',
#  'national steu',
#  'national wahrung',
#  'nato aufgelost',
#  'nato austret',
#  'neb deutsch',
#  'nebeneinkunft euro',
#  'nebeneinkunft veroffent',
#  'nehm betreuungsgeld',
#  'neu asylsuch',
#  'neu autos',
#  'neubau kohlekraftwerk',
#  'neuvermiet mietpreis',
#  'news losch',
#  'nord stream',
#  'nutzti landwirtschaft',
#  'nutzung autobahn',
#  'obergrenz gelt',
#  'offent dien',
#  'offent platz',
#  'offent raum',
#  'ohn angab',
#  'ohn kind',
#  'ohn konkret',
#  'ohn vorher',
#  'okolog landwirtschaft',
#  'okosteu abschaff',
#  'onlin durchsuch',
#  'ostse pipelin',
#  'partei fur',
#  'partei weiterhin',
#  'patent geschutzt',
#  'personalausweis aufgenomm',
#  'pfleg staatlich',
#  'pill danach',
#  'pipelin nord',
#  'pkw hoh',
#  'platz gesichtserkennungssoftwar',
#  'polit verfolgt',
#  'polizei innerhalb',
#  'praxisgebuhr abgeschafft',
#  'preis fur',
#  'privat arbeitsvermittl',
#  'privat bank',
#  'privat comput',
#  'produziert durf',
#  'projekt bekampf',
#  'projekt geg',
#  'raum ausgebaut',
#  'raum ausgeweitet',
#  'realschul gymnasi',
#  'recht anerkannt',
#  'recht hetero',
#  'rechtsanspruch ganztagsbetreu',
#  'rechtsextremismus ford',
#  'regelsatz fur',
#  'religionsgemeinschaft kirchensteu',
#  'religionsgemeinschaft staatlich',
#  'rent entsprech',
#  'renteneintritt abschlagsfrei',
#  'renteneintrittsalt wied',
#  'rentenversicher versichert',
#  'rezeptpflicht bleib',
#  'russland deutschland',
#  'rustungsexport deutsch',
#  'rustungsexport deutschland',
#  'rustungsexport verbot',
#  'schul inn',
#  'schuld erlass',
#  'schuld haft',
#  'schuldenbrems grundgesetz',
#  'schuldenschnitt fur',
#  'schulpolit erhalt',
#  'schulpolit zustand',
#  'schulsyst haupt',
#  'schwach bundesland',
#  'selb entscheid',
#  'selbstgenutzt wohneigentum',
#  'sicherheitsbehord verbot',
#  'sink gesetz',
#  'sofort afghanistan',
#  'solidaritatszuschlag end',
#  'solidaritatszuschlag vollstand',
#  'sollt deutschland',
#  'sollt flachendeck',
#  'sollt fur',
#  'sollt unabhang',
#  'sollt verbot',
#  'sollt vier',
#  'sollt volk',
#  'sonntag geoffnet',
#  'sozial wohnungsbau',
#  'spatest jahr',
#  'speicher kommunikationsdat',
#  'spend unternehm',
#  'spitzensteuersatz erhoht',
#  'spitzenverdi inn',
#  'sprachlich berucksicht',
#  'spracht besteh',
#  'spracht fur',
#  'staat allein',
#  'staat erst',
#  'staat finanziell',
#  'staat menschenrecht',
#  'staat offent',
#  'staat stark',
#  'staat weiterhin',
#  'staatlich anerkannt',
#  'staatlich beteil',
#  'staatlich festgelegt',
#  'staatlich hand',
#  'staatlich integrationsangebot',
#  'staatlich lohnersatzleist',
#  'staatsangehor behalt',
#  'staatsangehor besitz',
#  'staatsangehor weit',
#  'staatsschuld verwendet',
#  'staatsschuld vorrang',
#  'stark and',
#  'stark begrenzt',
#  'stark bish',
#  'stark finanziell',
#  'stark gefordert',
#  'stark reguliert',
#  'stark steig',
#  'stationar behandl',
#  'statt wehrpflicht',
#  'steig geplant',
#  'steinkohl weit',
#  'sterbehilf sollt',
#  'steu begunstigt',
#  'steu erhob',
#  'steu fur',
#  'steu zahl',
#  'straffrei abtreib',
#  'straftat inn',
#  'straftat kind',
#  'stream gas',
#  'strompreis staat',
#  'student bafog',
#  'studentinn student',
#  'studier schul',
#  'telefon internet',
#  'tempolimit autobahn',
#  'tempolimit deutsch',
#  'tempolimit gelt',
#  'terrorismusbekampf bundeswehr',
#  'tilg staatsschuld',
#  'traditionell famili',
#  'trag kopftuch',
#  'transportiert geplant',
#  'turkei europa',
#  'turkei vollmitgliedschaft',
#  'turkei vollwert',
#  'uber fallpauschal',
#  'uber hoh',
#  'uberwieg abbau',
#  'umsatz deutschland',
#  'unabhang einkomm',
#  'ungeachtet kulturell',
#  'union austret',
#  'union einsetz',
#  'union konn',
#  'union verstarkt',
#  'unt jahr',
#  'unternehm abgeschafft',
#  'unternehm gesenkt',
#  'unternehm gesetz',
#  'unternehm partei',
#  'unternehm selb',
#  'unternehm uber',
#  'unternehm weiterhin',
#  'unterschied geschlechtsidentitat',
#  'vat mutt',
#  'verandert lebensmittel',
#  'verband religionsgemeinschaft',
#  'verbind spracht',
#  'verbot durf',
#  'verbot rustungsexport',
#  'verbot tierversuch',
#  'verbrennungsmotor langfrist',
#  'verdeckt onlin',
#  'verfassungswidr partei',
#  'verfolgt gewahrt',
#  'verkauf cannabis',
#  'vermiet wohnungsmiet',
#  'vermieterinn vermiet',
#  'vermog besteuert',
#  'vermog wied',
#  'vermogenssteu eingefuhrt',
#  'vermogenssteu wied',
#  'veroffentlich unterschied',
#  'verpflicht staatlich',
#  'verpflichtet all',
#  'verpflichtet falschinformation',
#  'verstarkt eingesetzt',
#  'verstarkt mensch',
#  'verteidigungsausgab deutschland',
#  'verteidigungsausgab erhoh',
#  'verteidigungsetat erhoht',
#  'verteidigungspolit ausgebaut',
#  'verurteilt konn',
#  'verweig leistung',
#  'videouberwach offent',
#  'vier acht',
#  'volk direkt',
#  'volkermord europa',
#  'volksbegehr volksentscheid',
#  'volksentscheid bundeseb',
#  'volksinitiativ volksbegehr',
#  'volljahr deutsch',
#  'vollmitgliedschaft eu',
#  'vollstand abgeschafft',
#  'vollstand adoptionsrecht',
#  'vollstand staatlich',
#  'vollwert mitglied',
#  'vorher berat',
#  'vorrang gegenub',
#  'vorstand unternehm',
#  'vorubergeh notlos',
#  'wahl ab',
#  'wahl deutsch',
#  'wahl durf',
#  'wahlrecht 16',
#  'wahlrecht fur',
#  'wahrung behalt',
#  'wahrung zuruckkehr',
#  'wehrpflicht abgeschafft',
#  'wehrpflicht jetzig',
#  'weit staatsangehor',
#  'weit subventioniert',
#  'weiterhin erlaubt',
#  'weiterhin fur',
#  'weiterhin leiharbeiterinn',
#  'weiterhin leistung',
#  'weiterhin neb',
#  'weiterhin ohn',
#  'weiterhin patent',
#  'weiterhin polit',
#  'weiterhin projekt',
#  'weiterhin steu',
#  'weiterhin uber',
#  'weiterhin verbot',
#  'weiterhin zentral',
#  'welt schuld',
#  'wenig unterstutz',
#  'wert leitbild',
#  'wied eingefuhrt',
#  'wied einreisekontroll',
#  'wied gesenkt',
#  'wied steu',
#  'windenergi beendet',
#  'wohneigentum bestimmt',
#  'wohnungsbau bereitstell',
#  'wohnungsmiet erhoh',
#  'zeit angehor',
#  'zentral bestandteil',
#  'zentral erfasst',
#  'zon jed',
#  'zukunft braunkohl',
#  'zulass neu',
#  'zusammenarbeit mitgliedstaat',
#  'zustand schulpolit',
#  'zuwand verpflicht',
#  'zweit staatsangehor',
#  'zweit staatsburgerschaft']

# %%
# before this install sentence-transformers
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('distiluse-base-multilingual-cased-v1') # Pretrainened German model 
doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)
candidate_embeddings
# Out:
# array([[ 0.01304488,  0.02130779, -0.03088608, ..., -0.05067123,
#         -0.01180071,  0.01051449],
#        [ 0.0017441 , -0.01058046, -0.0089957 , ..., -0.05963491,
#          0.0459354 , -0.03064355],
#        [ 0.03089935, -0.04219492,  0.02294363, ..., -0.03779113,
#          0.05942431, -0.03729936],
#        ...,
#        [-0.01086026, -0.03508238,  0.00035662, ..., -0.02349827,
#          0.0175355 ,  0.01407066],
#        [ 0.02062604, -0.06402184, -0.00701085, ..., -0.00996454,
#         -0.02266434, -0.0425446 ],
#        [ 0.00653877, -0.04475578,  0.01760093, ..., -0.02355044,
#         -0.00263332, -0.05420139]], dtype=float32)

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_n = 10
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
keywords
# Out:
# ['deutschland verteidigungsausgab',
#  'verteidigungsausgab deutschland',
#  'deutsch grenz',
#  'generell tempolimit',
#  'tempolimit gelt',
#  'autobahn generell',
#  'all autobahn',
#  'tempolimit deutsch',
#  'deutsch autobahn',
#  'tempolimit autobahn']

# %%
import numpy as np
import itertools

# Max Sum Similarity

def max_sum_sim(doc_embedding, word_embeddings, words, top_n, nr_candidates):
    # Calculate distances and extract keywords
    distances = cosine_similarity(doc_embedding, candidate_embeddings)
    distances_candidates = cosine_similarity(candidate_embeddings, candidate_embeddings)

    # Get top_n words as candidates based on cosine similarity
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # Calculate the combination of words that are the least similar to each other
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=10, nr_candidates=10)
# Out:
# ['deutschland verteidigungsausgab',
#  'verteidigungsausgab deutschland',
#  'deutsch grenz',
#  'generell tempolimit',
#  'tempolimit gelt',
#  'autobahn generell',
#  'all autobahn',
#  'tempolimit deutsch',
#  'deutsch autobahn',
#  'tempolimit autobahn']

# %%
import numpy as np

# Maximal Marginal Relevance
def mmr(doc_embedding, word_embeddings, words, top_n, diversity):

    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)

    # Initialize candidates and already choose best keyword/keyphras
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # Update keywords & candidates
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

mmr(doc_embedding, candidate_embeddings, candidates, top_n=10, diversity=0.5)
# Out:
# ['tempolimit autobahn',
#  'deutschland verteidigungsausgab',
#  'all kind',
#  'ausbau kommunikationsinfrastruktur',
#  'weiterhin verbot',
#  'fingerabdruck personalausweis',
#  'euro wahrung',
#  'acht jahr',
#  'geschlechtsidentitat sprachlich',
#  'polizei innerhalb']
